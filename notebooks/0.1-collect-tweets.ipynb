# %% [markdown]
# ### Imports

# %%
from twarc.client2 import Twarc2
from twarc.expansions import ensure_flattened
from tqdm import tqdm
import configparser
import datetime
import time
import pandas as pd

# %% [markdown]
# ### Get API tokens

# %%
# Create a parser object and disable interpolation
parser = configparser.ConfigParser(interpolation=None)

# Read data from 'config.ini' file
parser.read("../config.ini")

# Access sections from the configuration file
parser.sections()

# Get 'bearer_token' from twitter section
bearer_token = parser.get('twitter', 'bearer_token')

# Create a Twarc2 instance with twitter credentials
client = Twarc2(bearer_token = bearer_token)

# %% [markdown]
# ### Search with `twarc2`

# %%
"""
Source code from: https://twarc-project.readthedocs.io/en/latest/api/library/
"""
# List of usernames
usernames = ['@danielapastrana', '@penileyramirez']

keywords = []

# Create an empty list to store data
tweets_list = []

# Iterate over our target users
for username in usernames:

    # Search for any tweets matching the query, Twitter API uses a boolean AND by default
    query = f"{username} lang:pt -is:retweet"

    # Specify the start time in UTC for the time period you want tweets fro
    start_time = datetime.datetime(2022, 1, 1, 0, 0, 0, 0, datetime.timezone.utc)
    # Specify the end time in UTC for the time period you want tweets from
    end_time = datetime.datetime(2022, 10, 31, 23, 59, 0, 0, datetime.timezone.utc)

    # 'search_results' is a generator, 'max_results' is max tweets per page, 100 max for full archive search with all expansions
    search_results = client.search_all(query=query, start_time=start_time, end_time=end_time, max_results=100)

    # Get all results page by page:
    for page in search_results:
        # Flatten results returning 1 tweet at a time, with expansions inline:
        for tweet in tqdm(ensure_flattened(page)):
            # Append tweets to empty list
            tweets_list.append(tweet)
            # time.sleep(5)
        # Get only one page for testing purposes
        break
    print(f'Collected tweets mentioning {username}')
# Out:
# 100%|██████████| 73/73 [00:00<00:00, 699050.67it/s]
# Collected tweets mentioning @danielapastrana
# 100%|██████████| 100/100 [00:00<00:00, 1067252.93it/s]
# Collected tweets mentioning @penileyramirez

# %% [markdown]
# ### Process data

# %%
# TODO: Avoid repeated column names 

# Convert json data to pandas dataframe
df = pd.DataFrame(tweets_list)
df
# Out:
#     in_reply_to_user_id            author_id  \
# 0              83683902            256545042
# 1            3087410276            381644638
# 2                   NaN            123151858
# 3              90663539           1674341816
# 4              90663539            111374936
# ..                  ...                  ...
# 168           386258984             56713141
# 169                 NaN            588749776
# 170           386258984            172488257
# 171           119618685  1363534801563619328
# 172           169243418  1293640606871363584
#
#                                      referenced_tweets  \
# 0    [{'type': 'replied_to', 'id': '158458001480825...
# 1    [{'type': 'replied_to', 'id': '158450019773583...
# 2    [{'type': 'quoted', 'id': '1583765682214252544...
# 3    [{'type': 'replied_to', 'id': '158370926257584...
# 4    [{'type': 'replied_to', 'id': '158275177131083...
# ..                                                 ...
# 168  [{'type': 'replied_to', 'id': '157569102544769...
# 169  [{'type': 'quoted', 'id': '1575720745996496901...
# 170  [{'type': 'replied_to', 'id': '157567552761604...
# 171  [{'type': 'replied_to', 'id': '157571781547413...
# 172  [{'type': 'replied_to', 'id': '157536317406432...
#
#                                          edit_controls  \
# 0    {'edits_remaining': 5, 'is_edit_eligible': Fal...
# 1    {'edits_remaining': 5, 'is_edit_eligible': Fal...
# 2    {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 3    {'edits_remaining': 5, 'is_edit_eligible': Fal...
# 4    {'edits_remaining': 5, 'is_edit_eligible': Fal...
# ..                                                 ...
# 168  {'edits_remaining': 5, 'is_edit_eligible': Fal...
# 169  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 170  {'edits_remaining': 5, 'is_edit_eligible': Fal...
# 171  {'edits_remaining': 5, 'is_edit_eligible': Fal...
# 172  {'edits_remaining': 5, 'is_edit_eligible': Fal...
#
#                    created_at edit_history_tweet_ids                   id  \
# 0    2022-10-26T12:17:08.000Z  [1585244134344122370]  1585244134344122370
# 1    2022-10-24T20:40:55.000Z  [1584646137910206464]  1584646137910206464
# 2    2022-10-23T03:08:03.000Z  [1584018787979825153]  1584018787979825153
# 3    2022-10-22T17:30:26.000Z  [1583873428309700610]  1583873428309700610
# 4    2022-10-19T15:18:38.000Z  [1582753096425668608]  1582753096425668608
# ..                        ...                    ...                  ...
# 168  2022-09-30T13:12:53.000Z  [1575836077075877889]  1575836077075877889
# 169  2022-09-30T12:58:57.000Z  [1575832573103992833]  1575832573103992833
# 170  2022-09-30T07:54:42.000Z  [1575756006474526720]  1575756006474526720
# 171  2022-09-30T05:24:06.000Z  [1575718103693938688]  1575718103693938688
# 172  2022-09-30T05:05:18.000Z  [1575713376608526336]  1575713376608526336
#
#          conversation_id                                           entities  \
# 0    1584580014808256519  {'mentions': [{'start': 0, 'end': 13, 'usernam...
# 1    1584500197735833602  {'mentions': [{'start': 0, 'end': 9, 'username...
# 2    1584018787979825153  {'urls': [{'start': 31, 'end': 54, 'url': 'htt...
# 3    1583709262575849473  {'mentions': [{'start': 0, 'end': 16, 'usernam...
# 4    1582751771310837766  {'mentions': [{'start': 0, 'end': 16, 'usernam...
# ..                   ...                                                ...
# 168  1575691024059359232  {'mentions': [{'start': 0, 'end': 9, 'username...
# 169  1575832573103992833  {'mentions': [{'start': 29, 'end': 41, 'userna...
# 170  1575675527616045059  {'annotations': [{'start': 68, 'end': 89, 'pro...
# 171  1575555262710448128  {'mentions': [{'start': 0, 'end': 12, 'usernam...
# 172  1575363174064324608  {'mentions': [{'start': 0, 'end': 12, 'usernam...
#
#     reply_settings                                               text  \
# 0         everyone  @felyxmarquez @AlJazeera @KaviChek @johnholman...
# 1         everyone  @PdPagina @Duiliorodriguez @danielapastrana Br...
# 2         everyone  Mira, @danielapastrana !!! 😍😍😍 https://t.co/bH...
# 3         everyone                            @danielapastrana Cínico
# 4         everyone                     @danielapastrana Felicidades!!
# ..             ...                                                ...
# 168       everyone           @menyvazq @penileyramirez ¿O sin testar?
# 169       everyone  Los nominados de esta semana @CarlosLoret @pen...
# 170       everyone  @menyvazq @penileyramirez @SEDENAmx @CarlosLor...
# 171       everyone  @javierglz21 @LAURABARRANCO @penileyramirez Se...
# 172       everyone  @alvaradoisa @GerardoReyesC @ahtziricardenas @...
#
#                                         public_metrics lang  \
# 0    {'retweet_count': 0, 'reply_count': 0, 'like_c...   pt
# 1    {'retweet_count': 1, 'reply_count': 0, 'like_c...   pt
# 2    {'retweet_count': 1, 'reply_count': 1, 'like_c...   es
# 3    {'retweet_count': 0, 'reply_count': 0, 'like_c...   pt
# 4    {'retweet_count': 0, 'reply_count': 0, 'like_c...   pt
# ..                                                 ...  ...
# 168  {'retweet_count': 0, 'reply_count': 0, 'like_c...   es
# 169  {'retweet_count': 0, 'reply_count': 0, 'like_c...   es
# 170  {'retweet_count': 0, 'reply_count': 0, 'like_c...   es
# 171  {'retweet_count': 0, 'reply_count': 0, 'like_c...   es
# 172  {'retweet_count': 1, 'reply_count': 0, 'like_c...   pt
#
#      possibly_sensitive                                             author  \
# 0                 False  {'verified': False, 'profile_image_url': 'http...
# 1                 False  {'url': 'https://t.co/rLAsTCxqHe', 'verified':...
# 2                 False  {'verified': False, 'profile_image_url': 'http...
# 3                 False  {'verified': False, 'profile_image_url': 'http...
# 4                 False  {'verified': False, 'profile_image_url': 'http...
# ..                  ...                                                ...
# 168               False  {'protected': False, 'profile_image_url': 'htt...
# 169               False  {'protected': False, 'profile_image_url': 'htt...
# 170               False  {'protected': False, 'profile_image_url': 'htt...
# 171               False  {'protected': False, 'profile_image_url': 'htt...
# 172               False  {'protected': False, 'profile_image_url': 'htt...
#
#                                       in_reply_to_user  \
# 0    {'url': 'https://t.co/YG16pMV2mO', 'verified':...
# 1    {'url': 'https://t.co/QaPDGxxwyk', 'verified':...
# 2                                                  NaN
# 3    {'url': 'https://t.co/mNb5ma3q2v', 'verified':...
# 4    {'url': 'https://t.co/mNb5ma3q2v', 'verified':...
# ..                                                 ...
# 168  {'protected': False, 'profile_image_url': 'htt...
# 169                                                NaN
# 170  {'protected': False, 'profile_image_url': 'htt...
# 171  {'protected': False, 'profile_image_url': 'htt...
# 172  {'protected': False, 'profile_image_url': 'htt...
#
#                                                __twarc  \
# 0    {'url': 'https://api.twitter.com/2/tweets/sear...
# 1    {'url': 'https://api.twitter.com/2/tweets/sear...
# 2    {'url': 'https://api.twitter.com/2/tweets/sear...
# 3    {'url': 'https://api.twitter.com/2/tweets/sear...
# 4    {'url': 'https://api.twitter.com/2/tweets/sear...
# ..                                                 ...
# 168  {'url': 'https://api.twitter.com/2/tweets/sear...
# 169  {'url': 'https://api.twitter.com/2/tweets/sear...
# 170  {'url': 'https://api.twitter.com/2/tweets/sear...
# 171  {'url': 'https://api.twitter.com/2/tweets/sear...
# 172  {'url': 'https://api.twitter.com/2/tweets/sear...
#
#                                            attachments  geo  \
# 0                                                  NaN  NaN
# 1                                                  NaN  NaN
# 2                                                  NaN  NaN
# 3                                                  NaN  NaN
# 4                                                  NaN  NaN
# ..                                                 ...  ...
# 168                                                NaN  NaN
# 169                                                NaN  NaN
# 170                                                NaN  NaN
# 171                                                NaN  NaN
# 172  {'media_keys': ['3_1575713374201122816'], 'med...  NaN
#
#                                    context_annotations
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 168                                                NaN
# 169  [{'domain': {'id': '10', 'name': 'Person', 'de...
# 170  [{'domain': {'id': '10', 'name': 'Person', 'de...
# 171                                                NaN
# 172                                                NaN
#
# [173 rows x 20 columns]

# %%
# TODO: Avoid repeated column names 

# Convert json data to pandas dataframe
df = pd.DataFrame(tweets_list)

# Normalize semi-structured JSON data into a flat table
public_metrics = pd.json_normalize(df['public_metrics'])
author = pd.json_normalize(df['author'])

# Concatenate daaframes
df_tweets = pd.concat([df, public_metrics, author], axis=1)

# Filter data
df_filtered = df_tweets[['lang', 'source', 'created_at', 'text', 'retweet_count',
                        'reply_count', 'like_count', 'quote_count', 'description', 'username',
                        'protected', 'id', 'verified', 'name', 'created_at', 'profile_image_url', 
                        'public_metrics.followers_count', 'public_metrics.following_count', 
                        'public_metrics.tweet_count', 'public_metrics.listed_count',
                        'location', 'pinned_tweet_id']]

# Show dataframe
df_filtered
# Save dataframe 
df_filtered.to_csv('../data/raw/twitter_mentions.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 14
#      11 df_tweets = pd.concat([df, public_metrics, author], axis=1)
#      13 # Filter data
# ---> 14 df_filtered = df_tweets[['lang', 'source', 'created_at', 'text', 'retweet_count',
#      15                         'reply_count', 'like_count', 'quote_count', 'description', 'username',
#      16                         'protected', 'id', 'verified', 'name', 'created_at', 'profile_image_url',
#      17                         'public_metrics.followers_count', 'public_metrics.following_count',
#      18                         'public_metrics.tweet_count', 'public_metrics.listed_count',
#      19                         'location', 'pinned_tweet_id']]
#      21 # Show dataframe
#      22 df_filtered
#
# File ~/.local/share/virtualenvs/attack_detector-WWidxv8W/lib/python3.8/site-packages/pandas/core/frame.py:3811, in DataFrame.__getitem__(self, key)
#    3809     if is_iterator(key):
#    3810         key = list(key)
# -> 3811     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3813 # take() does not accept boolean indexers
#    3814 if getattr(indexer, "dtype", None) == bool:
#
# File ~/.local/share/virtualenvs/attack_detector-WWidxv8W/lib/python3.8/site-packages/pandas/core/indexes/base.py:6113, in Index._get_indexer_strict(self, key, axis_name)
#    6110 else:
#    6111     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6113 self._raise_if_missing(keyarr, indexer, axis_name)
#    6115 keyarr = self.take(indexer)
#    6116 if isinstance(key, Index):
#    6117     # GH 42790 - Preserve name from an Index
#
# File ~/.local/share/virtualenvs/attack_detector-WWidxv8W/lib/python3.8/site-packages/pandas/core/indexes/base.py:6176, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6173     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6175 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6176 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['source'] not in index"
