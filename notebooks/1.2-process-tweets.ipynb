# %% [markdown]
# ### Imports

# %%
import os
import pandas as pd
import capir_transfronteriza2_2023.data.load as load

# %% [markdown]
# ### Load data

# %%
data_processed = load.data_processed

# %% [markdown]
# ### Read data

# %%
# Create a list of files from directory
files = os.listdir(data_processed)

df = pd.read_csv(f'{data_processed}/{files[7]}')
df
# Out:
# /tmp/ipykernel_32226/2920181540.py:4: DtypeWarning: Columns (11,27,28,29,31,35,39,41,42,43,68,69,70,71,72,73,74,75,76,77,78) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(f'{data_processed}/{files[7]}')
#                         id      conversation_id  \
# 0      1637917335267819527  1637887397361860608
# 1      1637693468976750593  1637693468976750593
# 2      1637659486616793088  1637658670099038211
# 3      1637658670099038211  1637658670099038211
# 4      1637646081776386052  1637546811429724160
# ...                    ...                  ...
# 50052           8282649461           8282649461
# 50053           6463558209           6463558209
# 50054           3130850859           3130850859
# 50055           3125595192           3125595192
# 50056           3111804971           3111804971
#
#        referenced_tweets.replied_to.id  referenced_tweets.retweeted.id  \
# ...
